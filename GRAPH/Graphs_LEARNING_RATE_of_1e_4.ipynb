# %% [markdown]
# <a href="https://colab.research.google.com/github/Chiamakac/IgboNER-Models/blob/main/GRAPH/Graphs_LEARNING_RATE_of_1e_4.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# **TrainLoss vs ValidLoss; Precision, Recall, F1 and Accuracy graph plot for IgboBERT, IgbomBERT, IgboXML-R, IgboDistillBERT fine-tuned result.**

# %% [markdown]
# ## Graphs

# %%
import matplotlib.pyplot as plt
import numpy as np

columns = ['TrainLoss', 'ValidLoss', 'Precision', 'Recall', 'F1', 'Accuracy']

# %% [markdown]
# **LEARNING RATE of 1e-4**

# %%
igbo_bert_results_dict = {k:[] for k in columns}
igbo_bert_results = """1	0.191500	0.183714	0.612950	0.710000	0.657915	0.936535
2	0.191500	0.212073	0.680412	0.660000	0.670051	0.941730
3	0.191500	0.211758	0.656477	0.751667	0.700855	0.944678
4	0.052400	0.230600	0.675758	0.743333	0.707937	0.948470
5	0.052400	0.217652	0.675799	0.740000	0.706444	0.948891
6	0.022300	0.250660	0.691824	0.733333	0.711974	0.947487
7	0.022300	0.266883	0.727564	0.756667	0.741830	0.953384
8	0.011200	0.269967	0.723602	0.776667	0.749196	0.951278
9	0.006000	0.321090	0.746269	0.750000	0.748130	0.951418
10	0.006000	0.300760	0.724570	0.771667	0.747377	0.951980
11	0.002400	0.297505	0.725832	0.763333	0.744110	0.950014
12	0.002400	0.311720	0.726845	0.771667	0.748585	0.951699
13	0.002700	0.346647	0.743590	0.773333	0.758170	0.953665
14	0.002700	0.324649	0.758853	0.750000	0.754401	0.954226
15	0.001700	0.322227	0.761345	0.755000	0.758159	0.954928
16	0.001700	0.302475	0.740385	0.770000	0.754902	0.956192
17	0.000800	0.298266	0.748823	0.795000	0.771221	0.955771
18	0.000500	0.301476	0.754386	0.788333	0.770986	0.954928
19	0.000500	0.298401	0.761600	0.793333	0.777143	0.955911
20	0.000500	0.301484	0.764423	0.795000	0.779412	0.956052"""

for r in igbo_bert_results.split('\n'):
  result = r.split()[1:]
  for i in range(len(columns)):
    igbo_bert_results_dict[columns[i]].append(float(result[i]))

# %%
igbo_mbert_results_dict = {k:[] for k in columns}
igbo_mbert_results = """1	0.169500	0.128593	0.728682	0.783333	0.755020	0.962644
2	0.169500	0.119064	0.802251	0.831667	0.816694	0.972467
3	0.169500	0.131608	0.755034	0.750000	0.752508	0.969814
4	0.067800	0.109487	0.777778	0.840000	0.807692	0.974546
5	0.067800	0.127297	0.825944	0.838333	0.832093	0.975407
6	0.043700	0.126837	0.823065	0.868333	0.845093	0.975048
7	0.043700	0.125044	0.775542	0.835000	0.804173	0.972109
8	0.028800	0.146728	0.811912	0.863333	0.836834	0.974762
9	0.016200	0.123855	0.808709	0.866667	0.836685	0.978131
10	0.016200	0.144533	0.835463	0.871667	0.853181	0.976482
11	0.011500	0.129612	0.822606	0.873333	0.847211	0.978347
12	0.011500	0.157839	0.833058	0.840000	0.836515	0.975048
13	0.006800	0.168714	0.835200	0.870000	0.852245	0.977414
14	0.006800	0.136655	0.827200	0.861667	0.844082	0.976913
15	0.005600	0.163031	0.827697	0.856667	0.841933	0.976841
16	0.001600	0.275571	0.779801	0.785000	0.782392	0.963152
17	0.001000	0.273858	0.787521	0.778333	0.782900	0.963720
18	0.000800	0.270366	0.803691	0.798333	0.801003	0.964532
19	0.000800	0.297436	0.805604	0.766667	0.785653	0.961529
20	0.000600	0.290177	0.797927	0.770000	0.783715	0.962016"""

for r in igbo_distilbert_results.split('\n'):
  result = r.split()[1:]
  for i in range(len(columns)):
    igbo_distilbert_results_dict[columns[i]].append(float(result[i]))

# %%
fig, axs = plt.subplots(4, 2, figsize=(12,15))
#IgboBert
axs[0, 0].plot(igbo_bert_results_dict['TrainLoss'])
axs[0, 0].plot(igbo_bert_results_dict['ValidLoss'])
axs[0, 0].set_title('(a)  IgboBERT - TrainLoss vs ValidLoss')
axs[0, 0].legend(['TrainLoss', 'ValidLoss'])
axs[0, 1].plot(igbo_bert_results_dict['Precision'])
axs[0, 1].plot(igbo_bert_results_dict['Recall'])
axs[0, 1].plot(igbo_bert_results_dict['F1'])
axs[0, 1].set_title('(b)  IgboBERT - Precision, Recall & F1')
axs[0, 1].legend(['Precision', 'Recall', 'F1'])


#IgbomBERT (Finetuned)
axs[1, 0].plot(igbo_mbert_results_dict['TrainLoss'])
axs[1, 0].plot(igbo_mbert_results_dict['ValidLoss'])
axs[1, 0].set_title('(c)  IgboMBERT - TrainLoss vs ValidLoss')
axs[1, 0].legend(['TrainLoss', 'ValidLoss'])
axs[1, 1].plot(igbo_mbert_results_dict['Precision'])
axs[1, 1].plot(igbo_mbert_results_dict['Recall'])
axs[1, 1].plot(igbo_mbert_results_dict['F1'])
axs[1, 1].set_title('(d)  IgboMBERT - Precision, Recall & F1')
axs[1, 1].legend(['Precision', 'Recall', 'F1'])


#IgboXML-R (Finetuned)
axs[2, 0].plot(igbo_xml_r_results_dict['TrainLoss'])
axs[2, 0].plot(igbo_xml_r_results_dict['ValidLoss'])
axs[2, 0].set_title('(e)  IgboXML-R - TrainLoss vs ValidLoss')
axs[2, 0].legend(['TrainLoss', 'ValidLoss'])
axs[2, 1].plot(igbo_xml_r_results_dict['Precision'])
axs[2, 1].plot(igbo_xml_r_results_dict['Recall'])
axs[2, 1].plot(igbo_xml_r_results_dict['F1'])
axs[2, 1].set_title('(f)  IgboXML-R - Precision, Recall & F1')
axs[2, 1].legend(['Precision', 'Recall', 'F1'])



#IgboDistilBERT (Finetuned)
axs[3, 0].plot(igbo_distilbert_results_dict['TrainLoss'])
axs[3, 0].plot(igbo_distilbert_results_dict['ValidLoss'])
axs[3, 0].set_title('(g)  IgboDistilBERT - TrainLoss vs ValidLoss')
axs[3, 0].legend(['TrainLoss', 'ValidLoss'])
axs[3, 1].plot(igbo_distilbert_results_dict['Precision'])
axs[3, 1].plot(igbo_distilbert_results_dict['Recall'])
axs[3, 1].plot(igbo_distilbert_results_dict['F1'])
axs[3, 1].set_title('(h)  IgboDistilBERT - Precision, Recall & F1')
axs[3, 1].legend(['Precision', 'Recall', 'F1'])
