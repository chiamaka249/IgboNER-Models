# %% [markdown]
# <a href="https://colab.research.google.com/github/Chiamakac/IgboNER-Models/blob/main/GRAPH/Graphs_LEARNING_RATE_of_2e_5.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# **TrainLoss vs ValidLoss; Precision, Recall, F1 and Accuracy graph plot for IgboBERT, IgbomBERT, IgboXML-R, IgboDistillBERT fine-tuned result.**

# %% [markdown]
# ## Graphs

# %%
import matplotlib.pyplot as plt
import numpy as np

columns = ['TrainLoss', 'ValidLoss', 'Precision', 'Recall', 'F1', 'Accuracy']

# %% [markdown]
# **LEARNING RATE of 2e-5**

# %%
igbo_bert_results_dict = {k:[] for k in columns}
igbo_bert_results = """1	0.234900	0.184247	0.605150	0.705000	0.651270	0.938360
2	0.234900	0.162431	0.683121	0.715000	0.698697	0.948189
3	0.234900	0.157811	0.700000	0.735000	0.717073	0.951137
4	0.085700	0.166981	0.684911	0.771667	0.725705	0.951699
5	0.085700	0.185172	0.709375	0.756667	0.732258	0.950857
6	0.036800	0.188902	0.674487	0.766667	0.717629	0.950716
7	0.036800	0.202219	0.713415	0.780000	0.745223	0.955209
8	0.017700	0.206185	0.712750	0.773333	0.741807	0.953524
9	0.008500	0.222333	0.737864	0.760000	0.748768	0.955911
10	0.008500	0.222891	0.723437	0.771667	0.746774	0.954367
11	0.005600	0.220256	0.719048	0.755000	0.736585	0.955630
12	0.005600	0.229856	0.728140	0.763333	0.745321	0.956192
13	0.003100	0.227688	0.742543	0.788333	0.764753	0.958719
14	0.003100	0.232610	0.732171	0.770000	0.750609	0.956052
15	0.001900	0.237902	0.750000	0.775000	0.762295	0.957035
16	0.001900	0.245163	0.722222	0.780000	0.750000	0.953805
17	0.001400	0.247386	0.732171	0.770000	0.750609	0.955771
18	0.001400	0.245546	0.724728	0.776667	0.749799	0.955350
19	0.001400	0.245001	0.728125	0.776667	0.751613	0.954928
20	0.000900	0.247700	0.732283	0.775000	0.753036	0.955490"""

for r in igbo_bert_results.split('\n'):
  result = r.split()[1:]
  for i in range(len(columns)):
    igbo_bert_results_dict[columns[i]].append(float(result[i]))

# %%
igbo_mbert_results_dict = {k:[] for k in columns}
igbo_mbert_results = """1	0.176800	0.154687	0.729970	0.820000	0.772370	0.958772
2	0.176800	0.106764	0.807571	0.853333	0.829822	0.972754
3	0.176800	0.114552	0.804878	0.825000	0.814815	0.970675
4	0.053000	0.097012	0.813397	0.850000	0.831296	0.977199
5	0.053000	0.120480	0.847650	0.871667	0.859491	0.977271
6	0.026700	0.121159	0.834951	0.860000	0.847291	0.975407
7	0.026700	0.135156	0.828800	0.863333	0.845714	0.975120
8	0.014400	0.120683	0.870492	0.885000	0.877686	0.979924
9	0.008400	0.139366	0.842365	0.855000	0.848635	0.976196
10	0.008400	0.141465	0.858075	0.876667	0.867271	0.978992
11	0.004800	0.144506	0.858293	0.888333	0.873055	0.977916
12	0.004800	0.148206	0.861842	0.873333	0.867550	0.978920
13	0.003000	0.141116	0.879139	0.885000	0.882060	0.979279
14	0.003000	0.151034	0.866776	0.878333	0.872517	0.979350
15	0.002800	0.148683	0.866232	0.885000	0.875515	0.980282
16	0.004600	0.206289	0.801653	0.808333	0.804979	0.966967
17	0.003800	0.212753	0.799669	0.805000	0.802326	0.965668
18	0.002900	0.218655	0.805743	0.795000	0.800336	0.966805
19	0.002900	0.218125	0.812606	0.795000	0.803707	0.966723
20	0.002100	0.221848	0.812606	0.795000	0.803707	0.966723"""

for r in igbo_distilbert_results.split('\n'):
  result = r.split()[1:]
  for i in range(len(columns)):
    igbo_distilbert_results_dict[columns[i]].append(float(result[i]))

# %%
fig, axs = plt.subplots(4, 2, figsize=(12,15))
#IgboBert
axs[0, 0].plot(igbo_bert_results_dict['TrainLoss'])
axs[0, 0].plot(igbo_bert_results_dict['ValidLoss'])
axs[0, 0].set_title('(a)  IgboBERT - TrainLoss vs ValidLoss')
axs[0, 0].legend(['TrainLoss', 'ValidLoss'])
axs[0, 1].plot(igbo_bert_results_dict['Precision'])
axs[0, 1].plot(igbo_bert_results_dict['Recall'])
axs[0, 1].plot(igbo_bert_results_dict['F1'])
axs[0, 1].set_title('(b)  IgboBERT - Precision, Recall & F1')
axs[0, 1].legend(['Precision', 'Recall', 'F1'])


#IgbomBERT (Finetuned)
axs[1, 0].plot(igbo_mbert_results_dict['TrainLoss'])
axs[1, 0].plot(igbo_mbert_results_dict['ValidLoss'])
axs[1, 0].set_title('(c)  IgboMBERT - TrainLoss vs ValidLoss')
axs[1, 0].legend(['TrainLoss', 'ValidLoss'])
axs[1, 1].plot(igbo_mbert_results_dict['Precision'])
axs[1, 1].plot(igbo_mbert_results_dict['Recall'])
axs[1, 1].plot(igbo_mbert_results_dict['F1'])
axs[1, 1].set_title('(d)  IgboMBERT - Precision, Recall & F1')
axs[1, 1].legend(['Precision', 'Recall', 'F1'])


#IgboXML-R (Finetuned)
axs[2, 0].plot(igbo_xml_r_results_dict['TrainLoss'])
axs[2, 0].plot(igbo_xml_r_results_dict['ValidLoss'])
axs[2, 0].set_title('(e)  IgboXML-R - TrainLoss vs ValidLoss')
axs[2, 0].legend(['TrainLoss', 'ValidLoss'])
axs[2, 1].plot(igbo_xml_r_results_dict['Precision'])
axs[2, 1].plot(igbo_xml_r_results_dict['Recall'])
axs[2, 1].plot(igbo_xml_r_results_dict['F1'])
axs[2, 1].set_title('(f)  IgboXML-R - Precision, Recall & F1')
axs[2, 1].legend(['Precision', 'Recall', 'F1'])



#IgboDistilBERT (Finetuned)
axs[3, 0].plot(igbo_distilbert_results_dict['TrainLoss'])
axs[3, 0].plot(igbo_distilbert_results_dict['ValidLoss'])
axs[3, 0].set_title('(g)  IgboDistilBERT - TrainLoss vs ValidLoss')
axs[3, 0].legend(['TrainLoss', 'ValidLoss'])
axs[3, 1].plot(igbo_distilbert_results_dict['Precision'])
axs[3, 1].plot(igbo_distilbert_results_dict['Recall'])
axs[3, 1].plot(igbo_distilbert_results_dict['F1'])
axs[3, 1].set_title('(h)  IgboDistilBERT - Precision, Recall & F1')
axs[3, 1].legend(['Precision', 'Recall', 'F1'])
